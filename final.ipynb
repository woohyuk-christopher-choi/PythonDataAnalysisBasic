# %%
import numpy as np
import matplotlib.pyplot as plt
sum_of_option_price = 0
mu_a, mu_b = 0.19, 0.10 # annual expected return for stock A and stock B
sig_a, sig_b = 0.41, 0.40 # annual expected volatility
s0_a, s0_b = 2434.40, 4023.61 # stock price at t0
T = 1 # simulate price evolution for the next year
delta_t = 1/365 
steps = T/delta_t
paths = 1000
rho = 0.5032 # correlation between stock A and stock B
cor_matrix = np.array([[1.0, rho],
                       [rho, 1.0]])
for i in range(0,paths):
    sd = np.diag([sig_a, sig_b]) 
    cov_matrix = np.dot(sd, np.dot(cor_matrix, sd)) 
    L = np.linalg.cholesky(cov_matrix) # Cholesky decomposition
    
    path_a = [s0_a]
    path_b = [s0_b]
    st_a, st_b = s0_a, s0_b 
    for i in range(int(steps)):
        V = L.dot(np.random.normal(0, 1, 2)) 
        st_a = st_a*np.exp((mu_a - 0.5*sig_a**2)*delta_t + sig_a*np.sqrt(delta_t)*V[0])
        st_b = st_b*np.exp((mu_b - 0.5*sig_b**2)*delta_t + sig_b*np.sqrt(delta_t)*V[1])
        path_a.append(st_a)
        path_b.append(st_b)
    
    
    if (st_a-s0_a)/s0_a - 0.05 > 0 or (st_b-s0_b)/s0_b - 0.05 > 0 :
        sum_of_option_price+= 1
    else :
        sum_of_option_price+= 0

    

print('expected_option_price before discounting:')
print(sum_of_option_price/paths)

print('expected_option_price after discounting:')
print((sum_of_option_price/paths)/(1+0.0199))
# Out:
# expected_option_price before discounting:
# 0.724
# expected_option_price after discounting:
# 0.7098735170114717

# %%
import numpy as np
import matplotlib.pyplot as plt
sum_of_option_price = 0
mu_a, mu_b = 0.19, 0.10 # annual expected return for stock A and stock B
sig_a, sig_b = 0.41, 0.40 # annual expected volatility
s0_a, s0_b = 2434.40, 4023.61 # stock price at t0
T = 1 # simulate price evolution for the next year
delta_t = 1/365 
steps = T/delta_t
paths = 10
rho = 0.5032 # correlation between stock A and stock B
cor_matrix = np.array([[1.0, rho],
                       [rho, 1.0]])
for i in range(0,paths):
    sd = np.diag([sig_a, sig_b]) 
    cov_matrix = np.dot(sd, np.dot(cor_matrix, sd)) 
    L = np.linalg.cholesky(cov_matrix) # Cholesky decomposition
    plt.figure(figsize = (12, 6))
    path_a = [s0_a]
    path_b = [s0_b]
    st_a, st_b = s0_a, s0_b
    for i in range(int(steps)):
        V = L.dot(np.random.normal(0, 1, 2)) 
        st_a = st_a*np.exp((mu_a - 0.5*sig_a**2)*delta_t + sig_a*np.sqrt(delta_t)*V[0])
        st_b = st_b*np.exp((mu_b - 0.5*sig_b**2)*delta_t + sig_b*np.sqrt(delta_t)*V[1])
        path_a.append(st_a)
        path_b.append(st_b)
        
        
        
    plt.plot(path_a, label = 'stock A', linewidth = 2)
    plt.plot(path_b, label = 'stock B', linewidth = 2)
    plt.legend()
    plt.title('Correlated Stock Movement Using Monte Carlo Simulation')
    plt.ylabel('stock price')
    plt.xlabel('steps')
    
    if (st_a-s0_a)/s0_a - 0.05 > 0 or (st_b-s0_b)/s0_b - 0.05 > 0 :
        sum_of_option_price+= 1
    else :
        sum_of_option_price+= 0



    
print('KOSPI:')
print(st_a)

print('S&P500:')
print(st_b)




    
print (sum_of_option_price)
    
print('expected_option_price before discounting:')
print(sum_of_option_price/paths)
# Out:
# KOSPI:
# 2302.1835021375396
# S&P500:
# 5163.928347761976
# 8
# expected_option_price before discounting:
# 0.8
